# %%
from netrc import netrc
import os
import requests
urs = "urs.earthdata.nasa.gov"  # Address to call for authentication
netrcDir = os.path.expanduser("~/.netrc")

earthadata_s3 = f"https://data.ornldaac.earthdata.nasa.gov/s3credentials"
r = requests.get(
            earthadata_s3.strip(),
            auth=(
                netrc(netrcDir).authenticators(urs)[0],
                netrc(netrcDir).authenticators(urs)[2],
            ),
        )

r.text
# Out:
# '{"accessKeyId": "ASIATDFCZRUYSXXHHJDI", "secretAccessKey": "2QTYAslAKo3V+8BuQVthIvEXPgwvjMwzRxHiWyRz", "sessionToken": "", "expiration": "2024-02-19 20:14:20+00:00"}'
