# %%
import geopandas as gpd
from scipy.spatial import KDTree

# %% [markdown]
# ## Pull Landsat Row/Path from Landsat and Clip to US

# %%
def process_geometry(geom, study_area):
    """
    Reproject geometry to study area projection and clip to study area. Reset index because features are dropped during clipping.
    """
    geom.to_crs(study_area.crs, inplace=True)
    geom = gpd.clip(geom, study_area)
    geom.reset_index(inplace=True, drop=True)
    return geom


us_states_shp = gpd.read_file(
    "https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_state_20m.zip"
)[["geometry", "STUSPS"]]
study_area = us_states_shp[
    us_states_shp["STUSPS"].isin(["AK", "HI", "PR", "VI", "GU", "AS", "MP", "UM"])
    == False
]  # Remove non-continental US states

landsat_scenes_shp = gpd.read_file(
    "https://d9-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/s3fs-public/atoms/files/WRS2_descending_0.zip"
)[["PATH", "ROW", "geometry"]]
landsat_scenes_shp_clipped = process_geometry(landsat_scenes_shp, study_area)

# %% [markdown]
# ## Visualize Landsat Scenes Geographically

# %%
landsat_scenes_shp_clipped.explore()

# You can see the Columns (PATH) start around 48 and the Rows (ROW) start around 26.
# Each cell represents a scene that was captured by Landsat (180x180km).
# There are about 500 scenes in the continental US.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_201c3da64b36e2f9d3bf6710d04e3b7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_201c3da64b36e2f9d3bf6710d04e3b7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_201c3da64b36e2f9d3bf6710d04e3b7f = L.map(
#                 &quot;map_201c3da64b36e2f9d3bf6710d04e3b7f&quot;,
#                 {
#                     center: [36.941244499999996, -95.837867],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_201c3da64b36e2f9d3bf6710d04e3b7f);
#
#
#
#
#
#             var tile_layer_974e532ac3cfe4ab86b02ebe9f9ff522 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_201c3da64b36e2f9d3bf6710d04e3b7f);
#
#
#             map_201c3da64b36e2f9d3bf6710d04e3b7f.fitBounds(
#                 [[24.498130999999997, -124.72583900000001], [49.384358, -66.949895]],
#                 {}
#             );
#
#
#         function geo_json_e85fe7124b7439f6fe54ac93b16ef915_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_e85fe7124b7439f6fe54ac93b16ef915_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_e85fe7124b7439f6fe54ac93b16ef915_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_e85fe7124b7439f6fe54ac93b16ef915_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_e85fe7124b7439f6fe54ac93b16ef915_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_e85fe7124b7439f6fe54ac93b16ef915.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_e85fe7124b7439f6fe54ac93b16ef915_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_e85fe7124b7439f6fe54ac93b16ef915 = L.geoJson(null, {
#                 onEachFeature: geo_json_e85fe7124b7439f6fe54ac93b16ef915_onEachFeature,
#
#                 style: geo_json_e85fe7124b7439f6fe54ac93b16ef915_styler,
#                 pointToLayer: geo_json_e85fe7124b7439f6fe54ac93b16ef915_pointToLayer
#         });
#
#         function geo_json_e85fe7124b7439f6fe54ac93b16ef915_add (data) {
#             geo_json_e85fe7124b7439f6fe54ac93b16ef915
#                 .addData(data)
#                 .addTo(map_201c3da64b36e2f9d3bf6710d04e3b7f);
#         }
#             geo_json_e85fe7124b7439f6fe54ac93b16ef915_add({&quot;bbox&quot;: [-124.72583900000001, 24.498130999999997, -66.949895, 49.384358], &quot;features&quot;: [{&quot;bbox&quot;: [-120.1953543342866, 33.215432, -119.427171, 33.95040259546614], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-120.02107933700955, 33.92507120683196], [-120.049682, 33.914563], [-120.121817, 33.895711999999996], [-120.17904899999999, 33.927994], [-120.1953543342866, 33.95040259546614], [-120.02107933700955, 33.92507120683196]]], [[[-119.510489, 33.307269], [-119.427171, 33.266023], [-119.429559, 33.228167], [-119.464725, 33.215432], [-119.545872, 33.233405999999995], [-119.578942, 33.278628], [-119.510489, 33.307269]]]],

# %% [markdown]
# ## Extract Path/Rows and put into a KDTree for nearest neighbor search

# %%
path_row_values = landsat_scenes_shp_clipped[["PATH", "ROW"]].values
path_row_values[:5]
# Out:
# array([[42, 37],
#        [41, 37],
#        [42, 36],
#        [41, 36],
#        [43, 36]])

# %%
tree = KDTree(path_row_values)
distances, indices = tree.query(
    [30, 32], k=5
)  # Find the 5 closest scenes to the path/row (30, 32) which is in the center of the continental US
# Visualize the 5 closest scenes to the point (100, 35)
landsat_scenes_shp_clipped.iloc[indices].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f2835a07c45dcc96580199d53b97251 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f2835a07c45dcc96580199d53b97251&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f2835a07c45dcc96580199d53b97251 = L.map(
#                 &quot;map_2f2835a07c45dcc96580199d53b97251&quot;,
#                 {
#                     center: [40.3363, -99.61595],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2f2835a07c45dcc96580199d53b97251);
#
#
#
#
#
#             var tile_layer_fdb4bf5b48755af96c8a38f807e3b6ca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2f2835a07c45dcc96580199d53b97251);
#
#
#             map_2f2835a07c45dcc96580199d53b97251.fitBounds(
#                 [[38.0024, -102.468], [42.6702, -96.7639]],
#                 {}
#             );
#
#
#         function geo_json_b56de39cd07c9c86b9610ce434f3ee9c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b56de39cd07c9c86b9610ce434f3ee9c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b56de39cd07c9c86b9610ce434f3ee9c_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b56de39cd07c9c86b9610ce434f3ee9c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b56de39cd07c9c86b9610ce434f3ee9c_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b56de39cd07c9c86b9610ce434f3ee9c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b56de39cd07c9c86b9610ce434f3ee9c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b56de39cd07c9c86b9610ce434f3ee9c = L.geoJson(null, {
#                 onEachFeature: geo_json_b56de39cd07c9c86b9610ce434f3ee9c_onEachFeature,
#
#                 style: geo_json_b56de39cd07c9c86b9610ce434f3ee9c_styler,
#                 pointToLayer: geo_json_b56de39cd07c9c86b9610ce434f3ee9c_pointToLayer
#         });
#
#         function geo_json_b56de39cd07c9c86b9610ce434f3ee9c_add (data) {
#             geo_json_b56de39cd07c9c86b9610ce434f3ee9c
#                 .addData(data)
#                 .addTo(map_2f2835a07c45dcc96580199d53b97251);
#         }
#             geo_json_b56de39cd07c9c86b9610ce434f3ee9c_add({&quot;bbox&quot;: [-102.468, 38.0024, -96.7639, 42.6702], &quot;features&quot;: [{&quot;bbox&quot;: [-100.923, 39.4284, -98.309, 41.2409], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-100.923, 39.7359], [-100.91723423423397, 39.75497137907224], [-100.90052774802189, 39.810231295004556], [-100.49048543188557, 41.166525109916954], [-100.4746293727385, 41.218972074788034], [-100.468, 41.2409], [-100.46778485994946, 41.240868690595704], [-98.309, 40.9267], [-98.3209847906016, 40.89082942117784], [-98.79825636218672, 39.4623516031475], [-98.8096, 39.4284], [-100.9228370164914, 39.735876285876365], [-100.923, 39.7359]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;301&qu
